# %% [markdown]
# **PAIS VENECIA**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Carga desde un archivo .xlsx sin indice
df = pd.read_excel("Venecia.xlsx")
df
# Out:
#                        id                                       listing_url  \
# 0                    6623                 https://www.airbnb.com/rooms/6623
# 1                   27116                https://www.airbnb.com/rooms/27116
# 2                   44527                https://www.airbnb.com/rooms/44527
# 3                   47383                https://www.airbnb.com/rooms/47383
# 4                   47549                https://www.airbnb.com/rooms/47549
# ...                   ...                                               ...
# 8317  1237620000000000000  https://www.airbnb.com/rooms/1237616852495526769
# 8318  1237620000000000000  https://www.airbnb.com/rooms/1237621692804609310
# 8319  1237690000000000000  https://www.airbnb.com/rooms/1237685862842036245
# 8320  1237700000000000000  https://www.airbnb.com/rooms/1237702795600914486
# 8321  1237710000000000000  https://www.airbnb.com/rooms/1237708481772340314
#
#            scrape_id last_scraped       source  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8322 entries, 0 to 8321
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            8322 non-null   int64
#  1   listing_url                                   8322 non-null   object
#  2   scrape_id                                     8322 non-null   int64
#  3   last_scraped                                  8322 non-null   datetime64[ns]
#  4   source                                        8322 non-null   object
#  5   name                                          8319 non-null   object
#  6   description                                   8003 non-null   object
#  7   neighborhood_overview                         4900 non-null   object
#  8   picture_url                                   8322 non-null   object
# ...

# %%
# Los registros de 5 "host name" diferentes

hosts_unicos = df['host_name'].dropna().unique()[:5]
filtro1 = df[df['host_name'].isin(hosts_unicos)]
filtro1
# Out:
#                        id                                       listing_url  \
# 0                    6623                 https://www.airbnb.com/rooms/6623
# 1                   27116                https://www.airbnb.com/rooms/27116
# 2                   44527                https://www.airbnb.com/rooms/44527
# 3                   47383                https://www.airbnb.com/rooms/47383
# 4                   47549                https://www.airbnb.com/rooms/47549
# ...                   ...                                               ...
# 7479  1126710000000000000  https://www.airbnb.com/rooms/1126705372749729269
# 7488  1128050000000000000  https://www.airbnb.com/rooms/1128051148370461241
# 7594  1138430000000000000  https://www.airbnb.com/rooms/1138429185253970295
# 7608  1142120000000000000  https://www.airbnb.com/rooms/1142122389161898431
# 7680  1154320000000000000  https://www.airbnb.com/rooms/1154324351843059921
#
#            scrape_id last_scraped       source  \
# ...

# %%
filtro1.to_csv("1.Los registros de 5 host name diferentes.csv")

# %%
df['host_since'] = pd.to_datetime(df['host_since'], errors='coerce')
filtro2 = df[df['host_since'] < '2019-01-01']
filtro2
# Out:
#                        id                                       listing_url  \
# 0                    6623                 https://www.airbnb.com/rooms/6623
# 1                   27116                https://www.airbnb.com/rooms/27116
# 2                   44527                https://www.airbnb.com/rooms/44527
# 3                   47383                https://www.airbnb.com/rooms/47383
# 4                   47549                https://www.airbnb.com/rooms/47549
# ...                   ...                                               ...
# 8297  1234170000000000000  https://www.airbnb.com/rooms/1234173393022273608
# 8299  1234740000000000000  https://www.airbnb.com/rooms/1234741811181873825
# 8304  1236160000000000000  https://www.airbnb.com/rooms/1236157349756437074
# 8305  1236240000000000000  https://www.airbnb.com/rooms/1236244429796957182
# 8310  1236880000000000000  https://www.airbnb.com/rooms/1236875180425924953
#
#            scrape_id last_scraped       source  \
# ...

# %%
df.to_csv("2.filtro comparacion.csv")

# %%
#Los registros de los host que responden "a más tardar en 1 día"
filtro3 = df[df['host_response_time'].str.contains('1 day', na=False, case=False)]
filtro3
# Out:
# Empty DataFrame
# ...

# %%
filtro3.to_csv("filtro3.cvs")

# %%
# d) Los registros que tengan "al menos 5 accommodates"
filtro4 = df[df['accommodates'] >= 5]
filtro4
# Out:
#                        id                                       listing_url  \
# 4                   47549                https://www.airbnb.com/rooms/47549
# 14                  72821                https://www.airbnb.com/rooms/72821
# 20                  77598                https://www.airbnb.com/rooms/77598
# 26                 129278               https://www.airbnb.com/rooms/129278
# 34                 146821               https://www.airbnb.com/rooms/146821
# ...                   ...                                               ...
# 8282  1231960000000000000  https://www.airbnb.com/rooms/1231957401047903224
# 8284  1232660000000000000  https://www.airbnb.com/rooms/1232662521239912836
# 8290  1233180000000000000  https://www.airbnb.com/rooms/1233175269619211513
# 8294  1234000000000000000  https://www.airbnb.com/rooms/1233995670486746142
# 8310  1236880000000000000  https://www.airbnb.com/rooms/1236875180425924953
#
#            scrape_id last_scraped           source  \
# ...

# %%
filtro4.to_csv("Filtro 4.csv")

# %%
#e) Los registros de los tipos de cuarto: "Entire home" y "Private room"
filtro5 = df[df['room_type'].isin(['Entire home/apt', 'Private room'])]
filtro5
# Out:
#                        id                                       listing_url  \
# 0                    6623                 https://www.airbnb.com/rooms/6623
# 1                   27116                https://www.airbnb.com/rooms/27116
# 2                   44527                https://www.airbnb.com/rooms/44527
# 4                   47549                https://www.airbnb.com/rooms/47549
# 5                   49656                https://www.airbnb.com/rooms/49656
# ...                   ...                                               ...
# 8317  1237620000000000000  https://www.airbnb.com/rooms/1237616852495526769
# 8318  1237620000000000000  https://www.airbnb.com/rooms/1237621692804609310
# 8319  1237690000000000000  https://www.airbnb.com/rooms/1237685862842036245
# 8320  1237700000000000000  https://www.airbnb.com/rooms/1237702795600914486
# 8321  1237710000000000000  https://www.airbnb.com/rooms/1237708481772340314
#
#            scrape_id last_scraped       source  \
# ...
